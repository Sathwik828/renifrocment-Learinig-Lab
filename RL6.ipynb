# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathwik828/renifrocment-Learinig-Lab/blob/main/RL6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %% [markdown]
# Random Agent for CliffWalking

# %%
import gymnasium as gym

# Create environment
env = gym.make("CliffWalking-v1")

num_episodes = 5
total_rewards = []

for episode in range(num_episodes):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    done = False

    while not done:

        # Select a random action
        action = env.action_space.sample()

        # Take action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Add reward
        total_reward += reward

        # Move to next state
        state = next_state

        # Check if episode is finished
        done = terminated or truncated

    total_rewards.append(total_reward)

    print("Episode", episode + 1, "Total Reward =", total_reward)

# Calculate average reward
average_reward = sum(total_rewards) / num_episodes

print("\nAverage Reward =", average_reward)

env.close()
# Out:
# Episode 1 Total Reward = -80383
# Episode 2 Total Reward = -187805
# Episode 3 Total Reward = -149266
# Episode 4 Total Reward = -70557
# Episode 5 Total Reward = -460
#
# Average Reward = -97694.2

# %% [markdown]
# Random Agent for Taxi

# %%
import gymnasium as gym

# Create Taxi environment
env = gym.make("Taxi-v4")

num_episodes = 5
total_rewards = []

for episode in range(num_episodes):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    done = False

    while not done:

        # Select a random action
        action = env.action_space.sample()

        # Take action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Add reward
        total_reward += reward

        # Move to next state
        state = next_state

        # Check if episode is finished
        done = terminated or truncated

    total_rewards.append(total_reward)

    print("Episode", episode + 1, "Total Reward =", total_reward)

# Calculate average reward
average_reward = sum(total_rewards) / num_episodes

print("\nAverage Reward =", average_reward)

env.close()
# Out:
# Episode 1 Total Reward = -830
# Episode 2 Total Reward = -785
# Episode 3 Total Reward = -902
# Episode 4 Total Reward = -821
# Episode 5 Total Reward = -767
#
# Average Reward = -821.0
